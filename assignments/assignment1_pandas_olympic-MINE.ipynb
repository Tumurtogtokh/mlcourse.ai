# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course
# Author: Arina Lopukhova (@erynn). Edited by [Yury Kashnitskiy](https://yorko.github.io) (@yorko) and Vadim Shestopalov (@vchulski). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# # <center>Assignment #1. Fall 2019
# ## <center>Exploratory data analysis of Olympic games with Pandas
#
# <img src='../../img/olympic_logo.png' width=50%>

# %% [markdown]
# Prior to working on the assignment, you'd better check out the corresponding course material:
#  - [Exploratory data analysis with Pandas](https://nbviewer.jupyter.org/github/Yorko/mlcourse_open/blob/master/jupyter_english/topic01_pandas_data_analysis/topic1_pandas_data_analysis.ipynb?flush_cache=true), the same as an interactive web-based [Kaggle Kernel](https://www.kaggle.com/kashnitsky/topic-1-exploratory-data-analysis-with-pandas)
#  - first lectures in mlcourse.ai [YouTube playlist ](https://www.youtube.com/watch?v=QKTuw4PNOsU&list=PLVlY_7IJCMJeRfZ68eVfEcu-UcN9BbwiX)
#  - you can also practice with demo assignments, which are simpler and already shared with solutions: [A1 demo](https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset), [solution](https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset-solution)
#
# ### Your task is to:
#  1. write code and perform computations in the cells below
#  2. choose answers in the [webform](https://docs.google.com/forms/d/1JxhQ9Bg4OpM3E5N47ZuRbILgDuMRbvEnUbDMZK8L-NU). Solutions will be shared only with those who've filled in this form
#  3. submit answers with some email and **remember it**! This will be your ID during the course. Specify your real full name in the form as well (no nicks allowed in the final top-100 [rating](https://mlcourse.ai/rating)). If in doubt, you can re-submit the form till the deadline for A1, no problem, but stick to only one email.
#
# ### <center> Deadline for A1: 2019 September 15, 20:59 GMT (London time)
#
# You'll get up to 10 credits for this assignment.
#
# ### How to get help
# In [ODS Slack](https://opendatascience.slack.com) (if you still don't have access, fill in the [form](https://docs.google.com/forms/d/10HAN5huM996snUKjsNYyT_oOlm2uOsTKulKurb3oiNM/) mentioned on the mlcourse.ai main page), we have a channel **#mlcourse_ai_news** with announcements from the course team.
# You can discuss the course content freely in the **#mlcourse_ai** channel (we still have a huge Russian-speaking group, they have a separate channel **#mlcourse_ai_rus**).
#
# Here's how you reply in a thread (press this dialog icon to drill down into a thread):
#
# <img src="../../img/start_a_thread.png" />
#
# Please stick to special threads *a1_q1-5_fall2019* and *a1_q6-10_fall2019* in **#mlcourse_ai_news** for your questions on A1. Help each other without sharing correct code and answers. Our TA **Vadim @vchulski** is there to help (only in the mentioned thread, do not write to him directly).
#
# Lastly, you can save useful messages by pinning them, further you can find pinned items on the top, just below the channel name:
#
# <img src="../../img/pinned_item.png" />
#
# ### Assignment
# __There are ten questions about 120 years of Olympic history in this task. Your task is to fill in the missing Python code and choose answers in [this web-form](https://docs.google.com/forms/d/1JxhQ9Bg4OpM3E5N47ZuRbILgDuMRbvEnUbDMZK8L-NU).__

# %% [markdown]
# Download the file `athlete_events.csv` from [here](https://drive.google.com/file/d/1f5v6Z2ayc7h698FG_98wP5x1Y2zZQeox/view?usp=sharing) (scraped by [rgriffin](https://www.randigriffin.com/) from www.sports-reference.com). The dataset has the following features:
#
# - __ID__ - Unique number for each athlete
# - __Name__ - Athlete's name
# - __Sex__ - M or F
# - __Age__ - Integer
# - __Height__ - In centimeters
# - __Weight__ - In kilograms
# - __Team__ - Team name
# - __NOC__ - National Olympic Committee 3-letter code
# - __Games__ - Year and season
# - __Year__ - Integer
# - __Season__ - Summer or Winter
# - __City__ - Host city
# - __Sport__ - Sport
# - __Event__ - Event
# - __Medal__ - Gold, Silver, Bronze, or NA

# %%
import pandas as pd

# %%
# Change the path to the dataset file if needed. 
PATH = '../data/athlete_events.csv'

# %%
df = pd.read_csv(PATH)
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
df[df['Sex']=='M'].sort_values(by=['Age', 'Year']).head()
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 142882   71691               Dimitrios Loundras   M  10.0     NaN     NaN
# 73461    37333  Carlos Bienvenido Front Barrera   M  11.0     NaN     NaN
# 249803  125092     tienne Nol Henri Vandernotte   M  12.0     NaN    37.0
# 249804  125092     tienne Nol Henri Vandernotte   M  12.0     NaN    37.0
# 79352    40296                 Alain C. Giletti   M  12.0     NaN     NaN
#
#                                  Team  NOC        Games  Year  Season  \
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896  Summer
# 73461                           Spain  ESP  1992 Summer  1992  Summer
# 249803                         France  FRA  1936 Summer  1936  Summer
# 249804                         France  FRA  1936 Summer  1936  Summer
# 79352                          France  FRA  1952 Winter  1952  Winter
#
#              City           Sport                                  Event  \
# 142882     Athina      Gymnastics  Gymnastics Men's Parallel Bars, Teams
# 73461   Barcelona          Rowing              Rowing Men's Coxed Eights
# 249803     Berlin          Rowing               Rowing Men's Coxed Pairs
# 249804     Berlin          Rowing               Rowing Men's Coxed Fours
# 79352        Oslo  Figure Skating           Figure Skating Men's Singles
#
#          Medal
# 142882  Bronze
# 73461      NaN
# 249803  Bronze
# 249804  Bronze
# 79352      NaN

# %%
df[(df['Sex']=='F') & (df['Year']==1992)].sort_values(by=['Age']).head()
# Out:
#            ID                        Name Sex   Age  Height  Weight     Team  \
# 120233  60854                  Judit Kiss   F  12.0   171.0    57.0  Hungary
# 120234  60854                  Judit Kiss   F  12.0   171.0    57.0  Hungary
# 102920  52072                Noriko Inada   F  13.0   167.0    60.0    Japan
# 80826   41040  Gina Elena Gogean (-Groza)   F  13.0   150.0    40.0  Romania
# 102919  52072                Noriko Inada   F  13.0   167.0    60.0    Japan
#
#         NOC        Games  Year  Season       City       Sport  \
# 120233  HUN  1992 Summer  1992  Summer  Barcelona    Swimming
# 120234  HUN  1992 Summer  1992  Summer  Barcelona    Swimming
# 102920  JPN  1992 Summer  1992  Summer  Barcelona    Swimming
# 80826   ROU  1992 Summer  1992  Summer  Barcelona  Gymnastics
# 102919  JPN  1992 Summer  1992  Summer  Barcelona    Swimming
#
#                                            Event Medal
# 120233     Swimming Women's 400 metres Freestyle   NaN
# 120234     Swimming Women's 800 metres Freestyle   NaN
# 102920    Swimming Women's 200 metres Backstroke   NaN
# 80826   Gymnastics Women's Individual All-Around   NaN
# 102919    Swimming Women's 100 metres Backstroke   NaN

# %% [markdown]
# __1. How old were the youngest male and female participants of the 1992 Olympics?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 16 and 15
# - 14 and 13
# - 13 and 11
# - 11 and 12

# %%
# You code here
# 11 and 12

# %% [markdown]
# __2. What was the percentage of male basketball players among all the male participants of the 2012 Olympics? Round the answer to the first decimal.__
#
# *Hint:* here and further if needed drop duplicated sportsmen to count only unique ones.
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 0.2
# - 1.5
# - 2.5
# - 7.7

# %%
df['Sport']
# Out:
# 0            Basketball
# 1                  Judo
# 2              Football
# 3            Tug-Of-War
# 4         Speed Skating
#               ...
# 271111             Luge
# 271112      Ski Jumping
# 271113      Ski Jumping
# 271114        Bobsleigh
# 271115        Bobsleigh
# Name: Sport, Length: 271116, dtype: object

# %%
df[(df['Sex']=='M') & (df['Year']==2012)].drop_duplicates(subset='Name')
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 98          34  Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0   187.0    76.0
# 134         48                    Abdelhak Aatakni   M  24.0     NaN    64.0
# 174         73                           Luc Abalo   M  27.0   182.0    86.0
# 197         91                      Emanuele Abate   M  27.0   190.0    80.0
# ...        ...                                 ...  ..   ...     ...     ...
# 271004  135516            Krzysztof Maciej Zwarycz   M  21.0   170.0    77.0
# 271020  135526                        Dniel Zwickl   M  27.0   178.0    71.0
# 271023  135528                       Marc Zwiebler   M  28.0   181.0    75.0
# 271090  135557                        Dominik ycki   M  38.0   192.0    95.0
# 271091  135558                  ukasz Tomasz ygado   M  32.0   200.0    89.0
#
#            Team  NOC        Games  Year  Season    City          Sport  \
# 1         China  CHN  2012 Summer  2012  Summer  London           Judo
# 98       France  FRA  2012 Summer  2012  Summer  London      Athletics
# 134     Morocco  MAR  2012 Summer  2012  Summer  London         Boxing
# 174      France  FRA  2012 Summer  2012  Summer  London       Handball
# 197       Italy  ITA  2012 Summer  2012  Summer  London      Athletics
# ...         ...  ...          ...   ...     ...     ...            ...
# 271004   Poland  POL  2012 Summer  2012  Summer  London  Weightlifting
# 271020  Hungary  HUN  2012 Summer  2012  Summer  London   Table Tennis
# 271023  Germany  GER  2012 Summer  2012  Summer  London      Badminton
# 271090   Poland  POL  2012 Summer  2012  Summer  London        Sailing
# 271091   Poland  POL  2012 Summer  2012  Summer  London     Volleyball
#
#                                      Event Medal
# 1             Judo Men's Extra-Lightweight   NaN
# 98            Athletics Men's 1,500 metres   NaN
# 134        Boxing Men's Light-Welterweight   NaN
# 174                Handball Men's Handball  Gold
# 197     Athletics Men's 110 metres Hurdles   NaN
# ...                                    ...   ...
# 271004    Weightlifting Men's Middleweight   NaN
# 271020          Table Tennis Men's Singles   NaN
# 271023             Badminton Men's Singles   NaN
# 271090   Sailing Men's Two Person Keelboat   NaN
# 271091         Volleyball Men's Volleyball   NaN
#
# [5858 rows x 15 columns]

# %%
df[(df['Sex']=='M') & (df['Year']==2012) & (df['Sport']=='Basketball')].drop_duplicates(subset='Name')
# Out:
#             ID                       Name Sex   Age  Height  Weight  \
# 1186       664       Kieron Robert Achara   M  29.0   208.0   110.0
# 6119      3444     Al-Farouq Ajiede Aminu   M  21.0   211.0    98.0
# 6120      3445  Abdul Wahab "Alade" Aminu   M  24.0   210.0   102.0
# 6631      3711        David Emil Andersen   M  32.0   211.0   102.0
# 8166      4505       Carmelo Kyan Anthony   M  28.0   203.0   109.0
# ...        ...                        ...  ..   ...     ...     ...
# 265717  132953                Yi Jianlian   M  24.0   213.0   113.0
# 265722  132955                      Yi Li   M  24.0   203.0    86.0
# 269053  134621               Zhang Zhaoxu   M  24.0   221.0   110.0
# 269401  134806                  Zhou Peng   M  22.0   206.0   102.0
# 269476  134838                 Zhu Fangyu   M  29.0   201.0   100.0
#
#                  Team  NOC        Games  Year  Season    City       Sport  \
# 1186    Great Britain  GBR  2012 Summer  2012  Summer  London  Basketball
# 6119          Nigeria  NGR  2012 Summer  2012  Summer  London  Basketball
# 6120          Nigeria  NGR  2012 Summer  2012  Summer  London  Basketball
# 6631        Australia  AUS  2012 Summer  2012  Summer  London  Basketball
# 8166    United States  USA  2012 Summer  2012  Summer  London  Basketball
# ...               ...  ...          ...   ...     ...     ...         ...
# 265717          China  CHN  2012 Summer  2012  Summer  London  Basketball
# 265722          China  CHN  2012 Summer  2012  Summer  London  Basketball
# 269053          China  CHN  2012 Summer  2012  Summer  London  Basketball
# 269401          China  CHN  2012 Summer  2012  Summer  London  Basketball
# 269476          China  CHN  2012 Summer  2012  Summer  London  Basketball
#
#                               Event Medal
# 1186    Basketball Men's Basketball   NaN
# 6119    Basketball Men's Basketball   NaN
# 6120    Basketball Men's Basketball   NaN
# 6631    Basketball Men's Basketball   NaN
# 8166    Basketball Men's Basketball  Gold
# ...                             ...   ...
# 265717  Basketball Men's Basketball   NaN
# 265722  Basketball Men's Basketball   NaN
# 269053  Basketball Men's Basketball   NaN
# 269401  Basketball Men's Basketball   NaN
# 269476  Basketball Men's Basketball   NaN
#
# [144 rows x 15 columns]

# %%
# You code here
144/5858.0 * 100
# Out:
# 2.4581768521679757

# %% [markdown]
# __3. What are the mean and standard deviation of height for female tennis players who participated in the 2000 Olympics? Round the answer to the first decimal.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 171.8 and 6.5
# - 179.4 and 10
# - 180.7 and 6.7
# - 182.4 and 9.1

# %%
q3 = df[(df['Sex']=='F') & (df['Year']==2000)]

# %%
q3[q3['Sport']=='Tennis']['Height'].std(), q3[q3['Sport']=='Tennis']['Height'].mean()
# Out:
# (6.4586725890776675, 171.792)

# %%
# You code here

# %% [markdown]
# __4. Find a sportsman who participated in the 2006 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - Judo
# - Bobsleigh
# - Skeleton
# - Boxing

# %%
q4 = df[df['Year']==2006]
q4.sort_values(by=['Weight'], ascending=False)['Sport']
# Out:
# 8102            Skeleton
# 38615         Ice Hockey
# 129597         Bobsleigh
# 129596         Bobsleigh
# 48536          Bobsleigh
#                ...
# 211812    Figure Skating
# 215400     Alpine Skiing
# 215401     Alpine Skiing
# 215402     Alpine Skiing
# 261779    Figure Skating
# Name: Sport, Length: 4382, dtype: object

# %%
# You code here

# %% [markdown]
# __5. How many times did John Aalberg participate in the Olympics held in different years?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 0
# - 1
# - 2
# - 3

# %%
df[df['Name']=='John Aalberg'].groupby('Games')['Year'].unique()
# Out:
# Games
# 1992 Winter    [1992]
# 1994 Winter    [1994]
# Name: Year, dtype: object

# %%
# You code here

# %% [markdown]
# __6. How many gold medals in tennis did sportspeople from the Switzerland team win at the 2008 Olympics? Count every medal from every sportsperson.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - 0
# - 1
# - 2
# - 3

# %%
df[(df['Team'] == 'Switzerland') & (df['Year']==2008) & (df['Sport'] == 'Tennis')].dropna()
# Out:
#             ID                Name Sex   Age  Height  Weight         Team  \
# 67290    34396       Roger Federer   M  26.0   185.0    80.0  Switzerland
# 257672  129042  Stanislas Wawrinka   M  23.0   183.0    79.0  Switzerland
#
#         NOC        Games  Year  Season     City   Sport                 Event  \
# 67290   SUI  2008 Summer  2008  Summer  Beijing  Tennis  Tennis Men's Doubles
# 257672  SUI  2008 Summer  2008  Summer  Beijing  Tennis  Tennis Men's Doubles
#
#        Medal
# 67290   Gold
# 257672  Gold

# %%
# You code here

# %% [markdown]
# __7. Is it true that Spain won fewer medals than Italy at the 2016 Olympics? Do not consider NaN values in _Medal_ column.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - Yes
# - No

# %%
df[(df['Team']=='Spain') & (df['Year']==2016)].dropna().count()
# Out:
# ID        43
# Name      43
# Sex       43
# Age       43
# Height    43
# Weight    43
# Team      43
# NOC       43
# Games     43
# Year      43
# Season    43
# City      43
# Sport     43
# Event     43
# Medal     43
# dtype: int64

# %%
df[(df['Team']=='Italy') & (df['Year']==2016)].dropna().count()
# Out:
# ID        70
# Name      70
# Sex       70
# Age       70
# Height    70
# Weight    70
# Team      70
# NOC       70
# Games     70
# Year      70
# Season    70
# City      70
# Sport     70
# Event     70
# Medal     70
# dtype: int64

# %%
# You code here

# %% [markdown]
# __8. What age category did the fewest and the most participants of the 2008 Olympics belong to?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - [45-55] and [25-35) correspondingly
# - [45-55] and [15-25) correspondingly
# - [35-45) and [25-35) correspondingly
# - [45-55] and [35-45) correspondingly

# %%
q8 = df[df['Year']==2008]
q8[(q8['Age'] <= 55) & (q8['Age'] >= 45)].count()
# Out:
# ID        119
# Name      119
# Sex       119
# Age       119
# Height    119
# Weight    117
# Team      119
# NOC       119
# Games     119
# Year      119
# Season    119
# City      119
# Sport     119
# Event     119
# Medal      16
# dtype: int64

# %%
q8[(q8['Age'] < 35) & (q8['Age'] >= 25)].count()
# Out:
# ID        6367
# Name      6367
# Sex       6367
# Age       6367
# Height    6320
# Weight    6324
# Team      6367
# NOC       6367
# Games     6367
# Year      6367
# Season    6367
# City      6367
# Sport     6367
# Event     6367
# Medal     1042
# dtype: int64

# %%
q8[(q8['Age'] < 25) & (q8['Age'] >= 15)].count()
# Out:
# ID        6294
# Name      6294
# Sex       6294
# Age       6294
# Height    6202
# Weight    6194
# Team      6294
# NOC       6294
# Games     6294
# Year      6294
# Season    6294
# City      6294
# Sport     6294
# Event     6294
# Medal      881
# dtype: int64

# %%
q8[(q8['Age'] < 45) & (q8['Age'] >= 35)].count()
# Out:
# ID        790
# Name      790
# Sex       790
# Age       790
# Height    780
# Weight    778
# Team      790
# NOC       790
# Games     790
# Year      790
# Season    790
# City      790
# Sport     790
# Event     790
# Medal     108
# dtype: int64

# %%
# You code here

# %% [markdown]
# __9. Is it true that there were Summer Olympics held in Atlanta? Is it true that there were Winter Olympics held in Squaw Valley?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - Yes, Yes
# - Yes, No
# - No, Yes
# - No, No

# %%
'Atlanta' in df[df['Season']=='Summer']['City']
# Out:
# False

# %%
'Squaw Valley' in df[df['Season']=='Winter']['City']
# Out:
# False

# %%
# You code here

# %% [markdown]
# __10. What is the absolute difference between the number of unique sports at the 1986 Olympics and 2002 Olympics?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - 3
# - 10
# - 15
# - 27

# %%
len(df[df['Year'] == 2002]['Sport'].unique())
# Out:
# 15

# %%
len(df[df['Year'] == 1986]['Sport'].unique())
# Out:
# 0

# %%
# You code here

# %% [markdown]
# That's it! Now go and do 30 push-ups! :)
